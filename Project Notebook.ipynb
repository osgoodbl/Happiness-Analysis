# %% [markdown]
# Happiness Analysis Project

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as py

# %%
index15 = pd.read_csv("./world-happiness-report/2015.csv", index_col=)

index16 = pd.read_csv("./world-happiness-report/2016.csv")

index17 = pd.read_csv("./world-happiness-report/2017.csv")

# %%
index15.drop(['Standard Error'], axis=1, inplace=True)

# %%
sns.heatmap(index15.corr());

# %%
index16.drop(['Lower Confidence Interval','Upper Confidence Interval'], axis=1, inplace=True)

# %%
sns.heatmap(index16.corr());

# %%
index17.drop(['Whisker.high','Whisker.low'], axis=1, inplace=True)

# %%
sns.heatmap(index17.corr());
